# %%
# Support embedding YouTube Videos in Notebooks
from IPython.display import YouTubeVideo

# %% [markdown]
# # Week 12 Part 4 #

# %% [markdown]
# If you use the conditional expectation as a predictor, it's no surprise that to quantify the error in that prediction you will need to define conditional variance.
#
# In this section we make that definition and then see how it can be used to find unconditional variance.

# %% [markdown]
# # <span style="color: darkblue">Conditional Variance</span> #

# %%
YouTubeVideo("UgIPOUjeR8Y")

# %% [markdown]
# # <span style="color: darkblue">Finding Variance by Conditioning</span> #

# %% [markdown]
# ### An Observation ###

# %%
YouTubeVideo("To07toH7lM8")

# %% [markdown]
# ### A Formula ###

# %%
YouTubeVideo("1yCGeGzwDpg")

# %% [markdown]
# ## Reading: Decomposition of Variance ##
# Another look at the how to find [variance by conditioning](http://prob140.org/textbook/Chapter_22/02_Variance_by_Conditioning.html#Decomposition-of-Variance), your first *analysis of variance* (ANOVA).

# %% [markdown]
# ## Reading: Example ##
# You spent quite some time studying what happens when you randomize the $p$ of a binomial. [Here](http://prob140.org/textbook/Chapter_22/03_Examples.html#Normal-with-a-Normal-Mean) is what happens to the mean and variance when you randomize the mean of a normal.

# %% [markdown]
# ## It's a good idea to go directly to the examples in the next section. ##
