# %%
# Support embedding YouTube Videos in Notebooks
from IPython.display import YouTubeVideo

# %% [markdown]
# # Moment Generating Functions

# %% [markdown]
# ## Exponential MGF

# %%
YouTubeVideo("eBDXGWJEqhE")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/eBDXGWJEqhE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Further Review Q25ab

# %%
YouTubeVideo("Yh3dhTw2i4Q")

# %% [markdown]
# ## Further Review Q11abc

# %% [markdown]
# ### 10a

# %%
YouTubeVideo("TKEaA_F_uOg")

# %% [markdown]
# ### 11a

# %%
YouTubeVideo("ROTEnSyNeUI")

# %% [markdown]
# ### 11b

# %%
YouTubeVideo("N36ia4ERQ3E")

# %% [markdown]
# ### 11c

# %%
YouTubeVideo("0mbMTykHckM")
