# %%
# Support embedding YouTube Videos in Notebooks
from IPython.display import YouTubeVideo

# %% [markdown]
# # Chernoff Bounds

# %% [markdown]
# ## Further Review Q11d

# %%
YouTubeVideo("XcuahYMk9Mk")

# %% [markdown]
# # Maximum Likelihood Estimation (MLE)

# %% [markdown]
# ## Further Review Q2

# %%
YouTubeVideo("HMP6Ca4M-Y0")

# %% [markdown]
# ## Further Review Q3

# %% [markdown]
# ### a

# %%
YouTubeVideo("1K01iSod8qQ")

# %% [markdown]
# ### b

# %%
YouTubeVideo("l_D5EsjCXJY")
