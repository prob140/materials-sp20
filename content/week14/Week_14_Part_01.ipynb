# %%
# Support embedding YouTube Videos in Notebooks
from IPython.display import YouTubeVideo

# %% [markdown]
# # Week 14 Part 1 #

# %% [markdown]
# The first two Parts this week goes back to Chapter 23, to properties of the multivariate normal. Now that many of you are acquainted with the last lab, the multivariate normal joint density and its implications will make more sense. So we'll take a break from regression to look at the density, and then return to regression to wrap up the course.
#
# The multivariate normal distribution has two parameters.

# %%
YouTubeVideo("s0iI43aX4TE")

# %% [markdown]
# ## Reading: The Formula for the Density ##
# Recall that there are [three equivalent ways](http://prob140.org/textbook/Chapter_23/02_Multivariate_Normal_Distribution.html#Multivariate-Normal-Distribution) of defining the multivariate normal. We have been using the definition in terms of linear combinations of i.i.d. standard normals. But we will now look at the joint density of a multivariate normal vector.
#
# So focus on the density at the start of the section. Here is a way to think about it.

# %%
YouTubeVideo("As-pC4ar1ws")

# %% [markdown]
# ## Reading: The Quadratic Form ##
# Go over the [qualitative discussion](http://prob140.org/textbook/Chapter_23/02_Multivariate_Normal_Distribution.html#Quadratic-Form), the graph of the density surface, and the cloud of points.

# %%
YouTubeVideo("dPT2wb8Nsjc")

# %% [markdown]
# The [math](http://prob140.org/textbook/Chapter_23/02_Multivariate_Normal_Distribution.html#Quadratic-Form), which is in the video, appears after the graphs.

# %% [markdown]
# ## Reading: The Constant of Integration ##
# This involves the [volume](http://prob140.org/textbook/Chapter_23/02_Multivariate_Normal_Distribution.html#Constant-of-Integration) created by the transformed unit vectors.

# %%
YouTubeVideo("PaAtfesCGtc")

# %% [markdown]
# The [math](http://prob140.org/textbook/Chapter_23/02_Multivariate_Normal_Distribution.html#Constant-of-Integration) is the same as in the video.

# %% [markdown]
# ## It's a good idea to keep going. An important use of the density is coming up. ##
